# %% [markdown]
# # Food101

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Configure GPU
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
BATCH_SIZE = 64
TARGET_SIZE = (350, 350)

# %% [markdown]
# ## Load up the dataset

# %%
#!rm -rf /root/.kaggle

# %%
# !mkdir /root/.kaggle
# !mv ./kaggle.json /root/.kaggle/kaggle.json
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets download -d kmader/food41

# %% [markdown]
# ## Data augmentation
# We might not need to augment our data

# %%
from keras.preprocessing.image import ImageDataGenerator
SEED = 111
gen_train = ImageDataGenerator(validation_split=0.2, width_shift_range=0.2, height_shift_range=0.2, rotation_range=25, shear_range=0.2, zoom_range=0.2,
                              horizontal_flip=True)
gen_valid = ImageDataGenerator(validation_split=0.2)
train_ds = gen_train.flow_from_directory("./food101/images", target_size=TARGET_SIZE, seed=SEED, subset='training')
valid_ds = gen_valid.flow_from_directory("./food101/images", target_size=TARGET_SIZE, seed=SEED, subset='validation')

class_names = train_ds.class_indices
num_classes = len(train_ds.class_indices)
# Out:
# Found 80800 images belonging to 101 classes.
# Found 20200 images belonging to 101 classes.

# %%
indices_class = [0 for _ in range(len(class_names))]
for k, v in class_names.items():
    indices_class[v] = k

# %%
fig = plt.figure(figsize=(15, 15))
cnt = 0
for images, labels in train_ds:
    if cnt >= BATCH_SIZE: break
    ax = plt.subplot(8, 8, cnt + 1)
    ax.imshow(images[0] / 255.0)
    ax.grid(False)
    ax.tick_params(bottom=False, left=False, labelbottom=False, labelleft=False)
    ax.set_title(indices_class[tf.math.argmax(labels[0], axis=-1)])
    cnt += 1

# %% [markdown]
# ## Defining the model

# %%
from keras.layers import Dense, Conv2D, BatchNormalization, ReLU, MaxPooling2D, GlobalAveragePooling2D, Softmax
from keras.layers import Input, Flatten, Dropout
from keras.optimizers import RMSprop

# %%
class Model(keras.models.Model):
    def __init__(self, num_classes):
        super(Model, self).__init__()
        self.num_classes = num_classes

        # Defining the base model
        self.base = keras.applications.EfficientNetB3(include_top=False, drop_connect_rate=0)
        self.base = keras.models.Model(inputs=self.base.inputs, outputs=self.base.output)
        self.base.trainable = False

        # Defining layers
        self.global_avg_pooling = GlobalAveragePooling2D(name='global_average_pooling')
        self.dropout = Dropout(0.3, name='dropout')
        self.classifier = Dense(units=num_classes, name='classifier')

        # Preprocessing
        self.norm = keras.applications.efficientnet.preprocess_input

    def call(self, input_tensor, training=False):
        x = self.norm(input_tensor)
        x = self.base(x, training=training)
        x = self.global_avg_pooling(x)

        if training: x = self.dropout(x)

        x = self.classifier(x)
        return x

    def train_step(self, data):
        x, y = data
        with tf.GradientTape() as tape:
            a = self.call(x, training=True)
            loss = self.compiled_loss(y, a)

        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        self.compiled_metrics.update_state(y, a)

        return {m.name : m.result() for m in self.metrics}

    def build(self, input_shape):
        inputs = Input(shape=input_shape[1:])
        self.model = keras.models.Model(inputs=inputs, outputs=self.call(inputs))
        super(Model, self).build(input_shape)

# %% [markdown]
# ### Training

# %%
model = Model(num_classes)
model.build([None, *TARGET_SIZE, 3])

checkpoint_callback = keras.callbacks.ModelCheckpoint('./checkpoints/', monitor='val_loss', save_weights_only=True, save_best_only=True, verbose=1)

loss = tf.losses.CategoricalCrossentropy(from_logits=True)
optimizer = RMSprop()
metrics = ['accuracy']

model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model_1 (Functional)        (None, None, None, 1536)  10783535
#
#  global_average_pooling (Glo  (None, 1536)             0
#  balAveragePooling2D)
#
#  dropout (Dropout)           multiple                  0 (unused)
#
#  classifier (Dense)          (None, 101)               155237
#
#  model_2 (Functional)        (None, 101)               10938772
#
# =================================================================
# Total params: 10,938,772
# Trainable params: 155,237
# Non-trainable params: 10,783,535
# _________________________________________________________________

# %%
history = model.fit(train_ds, epochs=3, validation_data=valid_ds, callbacks=[checkpoint_callback])
# Out:
# Epoch 1/3
# 2525/2525 [==============================] - ETA: 0s - loss: 1.6012 - accuracy: 0.6010
# Epoch 1: val_loss improved from inf to 1.18393, saving model to ./checkpoints/
# 2525/2525 [==============================] - 1737s 684ms/step - loss: 1.6012 - accuracy: 0.6010 - val_loss: 1.1839 - val_accuracy: 0.6909
# Epoch 2/3
# 2525/2525 [==============================] - ETA: 0s - loss: 1.1939 - accuracy: 0.6875
# Epoch 2: val_loss improved from 1.18393 to 1.12600, saving model to ./checkpoints/
# 2525/2525 [==============================] - 1718s 680ms/step - loss: 1.1939 - accuracy: 0.6875 - val_loss: 1.1260 - val_accuracy: 0.7021
# Epoch 3/3
# 2525/2525 [==============================] - ETA: 0s - loss: 1.1116 - accuracy: 0.7091
# Epoch 3: val_loss improved from 1.12600 to 1.10632, saving model to ./checkpoints/
# 2525/2525 [==============================] - 1814s 718ms/step - loss: 1.1116 - accuracy: 0.7091 - val_loss: 1.1063 - val_accuracy: 0.7116

# %% [markdown]
# ## Evaluations

# %%
fig = plt.figure(figsize=(8, 8))
ax = plt.subplot(2, 1, 1)
ax.plot(history.epoch, history.history['loss'], label='training')
ax.plot(history.epoch, history.history['val_loss'], label='validation')
ax.set_title('loss per epoch')
ax.set_xlabel('epoch')
ax.set_ylabel('loss')
ax.grid(True)
ax.legend()

ax = plt.subplot(2, 1, 2)
ax.plot(history.epoch, history.history['accuracy'], label='training')
ax.plot(history.epoch, history.history['val_accuracy'], label='validation')
ax.set_title('accuracy per epoch')
ax.set_xlabel('epoch')
ax.set_ylabel('accuracy')
ax.grid(True)
ax.legend();

fig.subplots_adjust(top=1, hspace=0.25)

# %%
y_true = []
y_pred = []

cnt = 0
for images, labels in valid_ds:
    print(f'\r{cnt} out of {valid_ds.n}', end='')
    if cnt >= valid_ds.n:
        break

    y_true.extend(tf.math.argmax(labels, axis=-1).numpy())
    y_pred.extend(tf.math.argmax(model.predict(images, verbose=0), axis=-1).numpy())
    cnt += valid_ds.batch_size
# Out:
# 20224 out of 20200

# %%
from sklearn.metrics import confusion_matrix, classification_report

fig = plt.figure(figsize=(20, 20))
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, cmap="Blues");

# %%
print(classification_report(y_true, y_pred, zero_division=True))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.42      0.54      0.47       200
#            1       0.64      0.79      0.70       200
#            2       0.77      0.71      0.74       200
#            3       0.65      0.74      0.69       200
#            4       0.67      0.63      0.65       200
#            5       0.65      0.49      0.56       200
#            6       0.70      0.88      0.78       200
#            7       0.93      0.81      0.86       200
#            8       0.59      0.32      0.42       200
#            9       0.74      0.71      0.73       200
#           10       0.65      0.56      0.60       200
#           11       0.79      0.80      0.79       200
#           12       0.67      0.82      0.74       200
#           13       0.68      0.72      0.70       200
#           14       0.57      0.73      0.64       200
#           15       0.54      0.54      0.54       200
#           16       0.80      0.84      0.82       200
#           17       0.52      0.57      0.54       200
#           18       0.62      0.63      0.62       200
#           19       0.60      0.79      0.68       200
#           20       0.81      0.79      0.80       200
#           21       0.54      0.61      0.58       200
#           22       0.58      0.32      0.41       200
#           23       0.81      0.85      0.83       200
#           24       0.80      0.82      0.81       200
#           25       0.83      0.74      0.79       200
#           26       0.64      0.49      0.56       200
#           27       0.89      0.81      0.85       200
#           28       0.86      0.73      0.79       200
#           29       0.74      0.81      0.78       200
#           30       0.84      0.85      0.85       200
#           31       0.73      0.70      0.72       200
#           32       0.85      0.82      0.83       200
#           33       0.99      0.98      0.99       200
#           34       0.78      0.80      0.79       200
#           35       0.88      0.68      0.77       200
#           36       0.76      0.67      0.71       200
#           37       0.70      0.40      0.50       200
#           38       0.85      0.78      0.81       200
#           39       0.42      0.48      0.45       200
#           40       0.93      0.89      0.91       200
#           41       0.66      0.82      0.73       200
#           42       0.65      0.55      0.60       200
#           43       0.77      0.72      0.75       200
#           44       0.79      0.80      0.79       200
#           45       0.75      0.93      0.83       200
#           46       0.67      0.70      0.68       200
#           47       0.61      0.52      0.56       200
#           48       0.80      0.70      0.75       200
#           49       0.64      0.64      0.64       200
#           50       0.68      0.47      0.55       200
#           51       0.77      0.91      0.83       200
#           52       0.67      0.75      0.71       200
#           53       0.78      0.80      0.79       200
#           54       0.76      0.92      0.83       200
#           55       0.67      0.85      0.75       200
#           56       0.64      0.45      0.53       200
#           57       0.65      0.51      0.57       200
#           58       0.74      0.69      0.71       200
#           59       0.72      0.44      0.54       200
#           60       0.72      0.79      0.75       200
#           61       0.73      0.88      0.80       200
#           62       0.77      0.68      0.72       200
#           63       0.89      0.89      0.89       200
#           64       0.78      0.93      0.85       200
#           65       0.74      0.90      0.81       200
#           66       0.68      0.69      0.69       200
#           67       0.61      0.55      0.58       200
#           68       0.78      0.84      0.81       200
#           69       0.91      0.86      0.89       200
#           70       0.81      0.82      0.82       200
#           71       0.80      0.74      0.77       200
#           72       0.85      0.66      0.74       200
#           73       0.58      0.64      0.61       200
#           74       0.74      0.81      0.77       200
#           75       0.78      0.88      0.82       200
#           76       0.75      0.86      0.80       200
#           77       0.40      0.57      0.47       200
#           78       0.72      0.90      0.80       200
#           79       0.84      0.65      0.73       200
#           80       0.80      0.64      0.71       200
#           81       0.74      0.78      0.76       200
#           82       0.48      0.56      0.52       200
#           83       0.84      0.71      0.77       200
#           84       0.60      0.71      0.65       200
#           85       0.70      0.74      0.72       200
#           86       0.91      0.80      0.85       200
#           87       0.62      0.52      0.56       200
#           88       0.88      0.93      0.91       200
#           89       0.55      0.63      0.59       200
#           90       0.70      0.84      0.77       200
#           91       0.78      0.94      0.85       200
#           92       0.75      0.76      0.75       200
#           93       0.40      0.39      0.39       200
#           94       0.74      0.66      0.70       200
#           95       0.78      0.71      0.74       200
#           96       0.56      0.70      0.62       200
#           97       0.82      0.79      0.80       200
#           98       0.68      0.56      0.62       200
#           99       0.53      0.47      0.50       200
#          100       0.79      0.69      0.73       200
#
#     accuracy                           0.71     20200
#    macro avg       0.72      0.71      0.71     20200
# weighted avg       0.72      0.71      0.71     20200

# %% [markdown]
# ## Fine Tuning

# %%
base_layers = model.layers[0]
for i in range(len(base_layers.layers)):
    print(f"{i:<4} -- {base_layers.layers[i].name}")
# Out:
# 0    -- input_1
# 1    -- rescaling
# 2    -- normalization
# 3    -- rescaling_1
# 4    -- stem_conv_pad
# 5    -- stem_conv
# 6    -- stem_bn
# 7    -- stem_activation
# 8    -- block1a_dwconv
# 9    -- block1a_bn
# 10   -- block1a_activation
# 11   -- block1a_se_squeeze
# 12   -- block1a_se_reshape
# 13   -- block1a_se_reduce
# 14   -- block1a_se_expand
# 15   -- block1a_se_excite
# 16   -- block1a_project_conv
# 17   -- block1a_project_bn
# 18   -- block1b_dwconv
# 19   -- block1b_bn
# 20   -- block1b_activation
# 21   -- block1b_se_squeeze
# 22   -- block1b_se_reshape
# 23   -- block1b_se_reduce
# 24   -- block1b_se_expand
# 25   -- block1b_se_excite
# 26   -- block1b_project_conv
# 27   -- block1b_project_bn
# 28   -- block1b_add
# 29   -- block2a_expand_conv
# 30   -- block2a_expand_bn
# 31   -- block2a_expand_activation
# 32   -- block2a_dwconv_pad
# 33   -- block2a_dwconv
# 34   -- block2a_bn
# 35   -- block2a_activation
# 36   -- block2a_se_squeeze
# 37   -- block2a_se_reshape
# 38   -- block2a_se_reduce
# 39   -- block2a_se_expand
# 40   -- block2a_se_excite
# 41   -- block2a_project_conv
# 42   -- block2a_project_bn
# 43   -- block2b_expand_conv
# 44   -- block2b_expand_bn
# 45   -- block2b_expand_activation
# 46   -- block2b_dwconv
# 47   -- block2b_bn
# 48   -- block2b_activation
# 49   -- block2b_se_squeeze
# 50   -- block2b_se_reshape
# 51   -- block2b_se_reduce
# 52   -- block2b_se_expand
# 53   -- block2b_se_excite
# 54   -- block2b_project_conv
# 55   -- block2b_project_bn
# 56   -- block2b_add
# 57   -- block2c_expand_conv
# 58   -- block2c_expand_bn
# 59   -- block2c_expand_activation
# 60   -- block2c_dwconv
# 61   -- block2c_bn
# 62   -- block2c_activation
# 63   -- block2c_se_squeeze
# 64   -- block2c_se_reshape
# 65   -- block2c_se_reduce
# 66   -- block2c_se_expand
# 67   -- block2c_se_excite
# 68   -- block2c_project_conv
# 69   -- block2c_project_bn
# 70   -- block2c_add
# 71   -- block3a_expand_conv
# 72   -- block3a_expand_bn
# 73   -- block3a_expand_activation
# 74   -- block3a_dwconv_pad
# 75   -- block3a_dwconv
# 76   -- block3a_bn
# 77   -- block3a_activation
# 78   -- block3a_se_squeeze
# 79   -- block3a_se_reshape
# 80   -- block3a_se_reduce
# 81   -- block3a_se_expand
# 82   -- block3a_se_excite
# 83   -- block3a_project_conv
# 84   -- block3a_project_bn
# 85   -- block3b_expand_conv
# 86   -- block3b_expand_bn
# 87   -- block3b_expand_activation
# 88   -- block3b_dwconv
# 89   -- block3b_bn
# 90   -- block3b_activation
# 91   -- block3b_se_squeeze
# 92   -- block3b_se_reshape
# 93   -- block3b_se_reduce
# 94   -- block3b_se_expand
# 95   -- block3b_se_excite
# 96   -- block3b_project_conv
# 97   -- block3b_project_bn
# 98   -- block3b_add
# 99   -- block3c_expand_conv
# 100  -- block3c_expand_bn
# 101  -- block3c_expand_activation
# 102  -- block3c_dwconv
# 103  -- block3c_bn
# 104  -- block3c_activation
# 105  -- block3c_se_squeeze
# 106  -- block3c_se_reshape
# 107  -- block3c_se_reduce
# 108  -- block3c_se_expand
# 109  -- block3c_se_excite
# 110  -- block3c_project_conv
# 111  -- block3c_project_bn
# 112  -- block3c_add
# 113  -- block4a_expand_conv
# 114  -- block4a_expand_bn
# 115  -- block4a_expand_activation
# 116  -- block4a_dwconv_pad
# 117  -- block4a_dwconv
# 118  -- block4a_bn
# 119  -- block4a_activation
# 120  -- block4a_se_squeeze
# 121  -- block4a_se_reshape
# 122  -- block4a_se_reduce
# 123  -- block4a_se_expand
# 124  -- block4a_se_excite
# 125  -- block4a_project_conv
# 126  -- block4a_project_bn
# 127  -- block4b_expand_conv
# 128  -- block4b_expand_bn
# 129  -- block4b_expand_activation
# 130  -- block4b_dwconv
# 131  -- block4b_bn
# 132  -- block4b_activation
# 133  -- block4b_se_squeeze
# 134  -- block4b_se_reshape
# 135  -- block4b_se_reduce
# 136  -- block4b_se_expand
# 137  -- block4b_se_excite
# 138  -- block4b_project_conv
# 139  -- block4b_project_bn
# 140  -- block4b_add
# 141  -- block4c_expand_conv
# 142  -- block4c_expand_bn
# 143  -- block4c_expand_activation
# 144  -- block4c_dwconv
# 145  -- block4c_bn
# 146  -- block4c_activation
# 147  -- block4c_se_squeeze
# 148  -- block4c_se_reshape
# 149  -- block4c_se_reduce
# 150  -- block4c_se_expand
# 151  -- block4c_se_excite
# 152  -- block4c_project_conv
# 153  -- block4c_project_bn
# 154  -- block4c_add
# 155  -- block4d_expand_conv
# 156  -- block4d_expand_bn
# 157  -- block4d_expand_activation
# 158  -- block4d_dwconv
# 159  -- block4d_bn
# 160  -- block4d_activation
# 161  -- block4d_se_squeeze
# 162  -- block4d_se_reshape
# 163  -- block4d_se_reduce
# 164  -- block4d_se_expand
# 165  -- block4d_se_excite
# 166  -- block4d_project_conv
# 167  -- block4d_project_bn
# 168  -- block4d_add
# 169  -- block4e_expand_conv
# 170  -- block4e_expand_bn
# 171  -- block4e_expand_activation
# 172  -- block4e_dwconv
# 173  -- block4e_bn
# 174  -- block4e_activation
# 175  -- block4e_se_squeeze
# 176  -- block4e_se_reshape
# 177  -- block4e_se_reduce
# 178  -- block4e_se_expand
# 179  -- block4e_se_excite
# 180  -- block4e_project_conv
# 181  -- block4e_project_bn
# 182  -- block4e_add
# 183  -- block5a_expand_conv
# 184  -- block5a_expand_bn
# 185  -- block5a_expand_activation
# 186  -- block5a_dwconv
# 187  -- block5a_bn
# 188  -- block5a_activation
# 189  -- block5a_se_squeeze
# 190  -- block5a_se_reshape
# 191  -- block5a_se_reduce
# 192  -- block5a_se_expand
# 193  -- block5a_se_excite
# 194  -- block5a_project_conv
# 195  -- block5a_project_bn
# 196  -- block5b_expand_conv
# 197  -- block5b_expand_bn
# 198  -- block5b_expand_activation
# 199  -- block5b_dwconv
# 200  -- block5b_bn
# 201  -- block5b_activation
# 202  -- block5b_se_squeeze
# 203  -- block5b_se_reshape
# 204  -- block5b_se_reduce
# 205  -- block5b_se_expand
# 206  -- block5b_se_excite
# 207  -- block5b_project_conv
# 208  -- block5b_project_bn
# 209  -- block5b_add
# 210  -- block5c_expand_conv
# 211  -- block5c_expand_bn
# 212  -- block5c_expand_activation
# 213  -- block5c_dwconv
# 214  -- block5c_bn
# 215  -- block5c_activation
# 216  -- block5c_se_squeeze
# 217  -- block5c_se_reshape
# 218  -- block5c_se_reduce
# 219  -- block5c_se_expand
# 220  -- block5c_se_excite
# 221  -- block5c_project_conv
# 222  -- block5c_project_bn
# 223  -- block5c_add
# 224  -- block5d_expand_conv
# 225  -- block5d_expand_bn
# 226  -- block5d_expand_activation
# 227  -- block5d_dwconv
# 228  -- block5d_bn
# 229  -- block5d_activation
# 230  -- block5d_se_squeeze
# 231  -- block5d_se_reshape
# 232  -- block5d_se_reduce
# 233  -- block5d_se_expand
# 234  -- block5d_se_excite
# 235  -- block5d_project_conv
# 236  -- block5d_project_bn
# 237  -- block5d_add
# 238  -- block5e_expand_conv
# 239  -- block5e_expand_bn
# 240  -- block5e_expand_activation
# 241  -- block5e_dwconv
# 242  -- block5e_bn
# 243  -- block5e_activation
# 244  -- block5e_se_squeeze
# 245  -- block5e_se_reshape
# 246  -- block5e_se_reduce
# 247  -- block5e_se_expand
# 248  -- block5e_se_excite
# 249  -- block5e_project_conv
# 250  -- block5e_project_bn
# 251  -- block5e_add
# 252  -- block6a_expand_conv
# 253  -- block6a_expand_bn
# 254  -- block6a_expand_activation
# 255  -- block6a_dwconv_pad
# 256  -- block6a_dwconv
# 257  -- block6a_bn
# 258  -- block6a_activation
# 259  -- block6a_se_squeeze
# 260  -- block6a_se_reshape
# 261  -- block6a_se_reduce
# 262  -- block6a_se_expand
# 263  -- block6a_se_excite
# 264  -- block6a_project_conv
# 265  -- block6a_project_bn
# 266  -- block6b_expand_conv
# 267  -- block6b_expand_bn
# 268  -- block6b_expand_activation
# 269  -- block6b_dwconv
# 270  -- block6b_bn
# 271  -- block6b_activation
# 272  -- block6b_se_squeeze
# 273  -- block6b_se_reshape
# 274  -- block6b_se_reduce
# 275  -- block6b_se_expand
# 276  -- block6b_se_excite
# 277  -- block6b_project_conv
# 278  -- block6b_project_bn
# 279  -- block6b_add
# 280  -- block6c_expand_conv
# 281  -- block6c_expand_bn
# 282  -- block6c_expand_activation
# 283  -- block6c_dwconv
# 284  -- block6c_bn
# 285  -- block6c_activation
# 286  -- block6c_se_squeeze
# 287  -- block6c_se_reshape
# 288  -- block6c_se_reduce
# 289  -- block6c_se_expand
# 290  -- block6c_se_excite
# 291  -- block6c_project_conv
# 292  -- block6c_project_bn
# 293  -- block6c_add
# 294  -- block6d_expand_conv
# 295  -- block6d_expand_bn
# 296  -- block6d_expand_activation
# 297  -- block6d_dwconv
# 298  -- block6d_bn
# 299  -- block6d_activation
# 300  -- block6d_se_squeeze
# 301  -- block6d_se_reshape
# 302  -- block6d_se_reduce
# 303  -- block6d_se_expand
# 304  -- block6d_se_excite
# 305  -- block6d_project_conv
# 306  -- block6d_project_bn
# 307  -- block6d_add
# 308  -- block6e_expand_conv
# 309  -- block6e_expand_bn
# 310  -- block6e_expand_activation
# 311  -- block6e_dwconv
# 312  -- block6e_bn
# 313  -- block6e_activation
# 314  -- block6e_se_squeeze
# 315  -- block6e_se_reshape
# 316  -- block6e_se_reduce
# 317  -- block6e_se_expand
# 318  -- block6e_se_excite
# 319  -- block6e_project_conv
# 320  -- block6e_project_bn
# 321  -- block6e_add
# 322  -- block6f_expand_conv
# 323  -- block6f_expand_bn
# 324  -- block6f_expand_activation
# 325  -- block6f_dwconv
# 326  -- block6f_bn
# 327  -- block6f_activation
# 328  -- block6f_se_squeeze
# 329  -- block6f_se_reshape
# 330  -- block6f_se_reduce
# 331  -- block6f_se_expand
# 332  -- block6f_se_excite
# 333  -- block6f_project_conv
# 334  -- block6f_project_bn
# 335  -- block6f_add
# 336  -- block7a_expand_conv
# 337  -- block7a_expand_bn
# 338  -- block7a_expand_activation
# 339  -- block7a_dwconv
# 340  -- block7a_bn
# 341  -- block7a_activation
# 342  -- block7a_se_squeeze
# 343  -- block7a_se_reshape
# 344  -- block7a_se_reduce
# 345  -- block7a_se_expand
# 346  -- block7a_se_excite
# 347  -- block7a_project_conv
# 348  -- block7a_project_bn
# 349  -- block7b_expand_conv
# 350  -- block7b_expand_bn
# 351  -- block7b_expand_activation
# 352  -- block7b_dwconv
# 353  -- block7b_bn
# 354  -- block7b_activation
# 355  -- block7b_se_squeeze
# 356  -- block7b_se_reshape
# 357  -- block7b_se_reduce
# 358  -- block7b_se_expand
# 359  -- block7b_se_excite
# 360  -- block7b_project_conv
# 361  -- block7b_project_bn
# 362  -- block7b_add
# 363  -- top_conv
# 364  -- top_bn
# 365  -- top_activation

# %%
fine_tune_at = 353
model.layers[0].trainable = True
for i in range(fine_tune_at):
    model.layers[0].layers[i].trainable = False

for i in range(len(base_layers.layers)):
    if isinstance(base_layers.layers[i], keras.layers.BatchNormalization):
        model.layers[0].layers[i].trainable = False

# Compile
model.summary()

loss = tf.losses.CategoricalCrossentropy(from_logits=True)
optimizer = tf.optimizers.Adam(learning_rate=1e-4)
metrics = ['accuracy']

model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model_1 (Functional)        (None, None, None, 1536)  10783535
#
#  global_average_pooling (Glo  (None, 1536)             0
#  balAveragePooling2D)
#
#  dropout (Dropout)           multiple                  0
#
#  classifier (Dense)          (None, 101)               155237
#
#  model_2 (Functional)        (None, 101)               10938772
#
# =================================================================
# Total params: 10,938,772
# Trainable params: 2,074,565
# Non-trainable params: 8,864,207
# _________________________________________________________________

# %%
fine_tune_history = model.fit(train_ds, epochs=5, validation_data=valid_ds, callbacks=[checkpoint_callback])
# Out:
# Epoch 1/5
# 2525/2525 [==============================] - ETA: 0s - loss: 0.9561 - accuracy: 0.7451
# Epoch 1: val_loss improved from 1.10632 to 0.96197, saving model to ./checkpoints/
# 2525/2525 [==============================] - 1750s 689ms/step - loss: 0.9561 - accuracy: 0.7451 - val_loss: 0.9620 - val_accuracy: 0.7453
# Epoch 2/5
# 2525/2525 [==============================] - ETA: 0s - loss: 0.8002 - accuracy: 0.7815
# Epoch 2: val_loss improved from 0.96197 to 0.90799, saving model to ./checkpoints/
# 2525/2525 [==============================] - 1697s 672ms/step - loss: 0.8002 - accuracy: 0.7815 - val_loss: 0.9080 - val_accuracy: 0.7595
# Epoch 3/5
# 2525/2525 [==============================] - ETA: 0s - loss: 0.6892 - accuracy: 0.8072
# Epoch 3: val_loss improved from 0.90799 to 0.90755, saving model to ./checkpoints/
# 2525/2525 [==============================] - 1696s 671ms/step - loss: 0.6892 - accuracy: 0.8072 - val_loss: 0.9075 - val_accuracy: 0.7639
# Epoch 4/5
# 2525/2525 [==============================] - ETA: 0s - loss: 0.6019 - accuracy: 0.8302
# Epoch 4: val_loss improved from 0.90755 to 0.90494, saving model to ./checkpoints/
# 2525/2525 [==============================] - 1695s 671ms/step - loss: 0.6019 - accuracy: 0.8302 - val_loss: 0.9049 - val_accuracy: 0.7650
# Epoch 5/5
# 2525/2525 [==============================] - ETA: 0s - loss: 0.5286 - accuracy: 0.8483
# Epoch 5: val_loss did not improve from 0.90494
# 2525/2525 [==============================] - 1697s 672ms/step - loss: 0.5286 - accuracy: 0.8483 - val_loss: 0.9210 - val_accuracy: 0.7659

# %%
epochs = np.arange(len(history.epoch) + len(fine_tune_history.epoch))
loss = np.hstack((history.history['loss'], fine_tune_history.history['loss']))
valid_loss = np.hstack((history.history['val_loss'], fine_tune_history.history['val_loss']))
acc = np.hstack((history.history['accuracy'], fine_tune_history.history['accuracy']))
valid_acc = np.hstack((history.history['val_accuracy'], fine_tune_history.history['val_accuracy']))

fig = plt.figure(figsize=(8, 8))
ax = plt.subplot(2, 1, 1)
ax.plot(epochs, loss, label='training')
ax.plot(epochs, valid_loss, label='validation')
ax.set_title('loss per epoch')
ax.set_xlabel('epoch')
ax.set_ylabel('loss')
ax.grid(True)
ax.legend()

ax = plt.subplot(2, 1, 2)
ax.plot(epochs, acc, label='training')
ax.plot(epochs, valid_acc, label='validation')
ax.set_title('accuracy per epoch')
ax.set_xlabel('epoch')
ax.set_ylabel('accuracy')
ax.grid(True)
ax.legend();

fig.subplots_adjust(top=1, hspace=0.25)

# %%
y_true = []
y_pred = []

cnt = 0
for images, labels in valid_ds:
    print(f'\r{cnt} out of {valid_ds.n}', end='')
    if cnt >= valid_ds.n:
        break

    y_true.extend(tf.math.argmax(labels, axis=-1).numpy())
    y_pred.extend(tf.math.argmax(model.predict(images, verbose=0), axis=-1).numpy())
    cnt += valid_ds.batch_size
# Out:
# 288 out of 20200
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[22], line 11
#       8     break
#      10 y_true.extend(tf.math.argmax(labels, axis=-1).numpy())
# ---> 11 y_pred.extend(tf.math.argmax(model.predict(images, verbose=0), axis=-1).numpy())
#      12 cnt += valid_ds.batch_size
#
# File ~/miniconda3/envs/tf/lib/python3.11/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/envs/tf/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'model/model_1/block2a_expand_bn/FusedBatchNormV3' defined at (most recent call last):
#     File "<frozen runpy>", line 198, in _run_module_as_main
#     File "<frozen runpy>", line 88, in _run_code
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#       app.start()
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 728, in start
#       self.io_loop.start()
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#       self._run_once()
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#       handle._run()
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#       await self.process_one()
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#       await dispatch(*args)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#       await result
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_150823/521243384.py", line 11, in <module>
#       y_pred.extend(tf.math.argmax(model.predict(images, verbose=0), axis=-1).numpy())
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/engine/training.py", line 2382, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/engine/training.py", line 2169, in predict_function
#       return step_function(self, iterator)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/engine/training.py", line 2155, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/engine/training.py", line 2143, in run_step
#       outputs = model.predict_step(data)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/engine/training.py", line 2111, in predict_step
#       return self(x, training=False)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/engine/training.py", line 558, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/engine/base_layer.py", line 1145, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/tmp/ipykernel_150823/615803855.py", line 21, in call
#       x = self.base(x, training=training)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/engine/training.py", line 558, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/engine/base_layer.py", line 1145, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/engine/functional.py", line 512, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/engine/functional.py", line 669, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/engine/base_layer.py", line 1145, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/layers/normalization/batch_normalization.py", line 922, in call
#       outputs = self._fused_batch_norm(
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/layers/normalization/batch_normalization.py", line 688, in _fused_batch_norm
#       output, mean, variance = control_flow_util.smart_cond(
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/utils/control_flow_util.py", line 108, in smart_cond
#       return tf.__internal__.smart_cond.smart_cond(
#     File "/home/alireza/miniconda3/envs/tf/lib/python3.11/site-packages/keras/layers/normalization/batch_normalization.py", line 677, in _fused_batch_norm_inference
#       return tf.compat.v1.nn.fused_batch_norm(
# Node: 'model/model_1/block2a_expand_bn/FusedBatchNormV3'
# OOM when allocating tensor with shape[32,144,175,175] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model/model_1/block2a_expand_bn/FusedBatchNormV3}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_predict_function_212885]

# %%
fig = plt.figure(figsize=(20, 20))
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, cmap="Blues");

# %%
print(classification_report(y_true, y_pred, zero_division=True))

# %% [markdown]
# ## Summary
